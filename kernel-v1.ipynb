# %%
import numpy as np
import pandas as pd
import os, random, time, datetime, json
from pandas.io.json import json_normalize
from ast import literal_eval

# Common Model Algorithms
from sklearn import svm, tree, linear_model, neighbors, naive_bayes, ensemble, discriminant_analysis, gaussian_process
from xgboost import XGBClassifier

# Common Model Helpers
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn import feature_selection
from sklearn import model_selection
from sklearn import metrics

from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import warnings
warnings.filterwarnings('ignore')

print(os.listdir("."))
# Out:
# ['.DS_Store', 'input', '.gitignore', '.ipynb_checkpoints', '.git', 'kernel-v1.ipynb']

# %% [markdown]
# ## First, let's explore a small subsample of the data

# %%
# %%time
small_sample = pd.read_csv('input/train_v2.csv', nrows=10000)
# Out:
# CPU times: user 1.41 s, sys: 244 ms, total: 1.65 s
# Wall time: 3.14 s

# %%
print(small_sample.info())
small_sample.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
# channelGrouping         10000 non-null object
# customDimensions        10000 non-null object
# date                    10000 non-null int64
# device                  10000 non-null object
# fullVisitorId           10000 non-null uint64
# geoNetwork              10000 non-null object
# hits                    10000 non-null object
# socialEngagementType    10000 non-null object
# totals                  10000 non-null object
# trafficSource           10000 non-null object
# visitId                 10000 non-null int64
# visitNumber             10000 non-null int64
# visitStartTime          10000 non-null int64
# dtypes: int64(4), object(8), uint64(1)
# memory usage: 1015.7+ KB
# None
#   channelGrouping                              customDimensions      date  \
# 0  Organic Search             [{'index': '4', 'value': 'EMEA'}]  20171016
# 1        Referral    [{'index': '4', 'value': 'North America'}]  20171016
# 2          Direct    [{'index': '4', 'value': 'North America'}]  20171016
# 3  Organic Search             [{'index': '4', 'value': 'EMEA'}]  20171016
# 4  Organic Search  [{'index': '4', 'value': 'Central America'}]  20171016
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Firefox", "browserVersion": "not ...  3162355547410993243
# 1  {"browser": "Chrome", "browserVersion": "not a...  8934116514970143966
# 2  {"browser": "Chrome", "browserVersion": "not a...  7992466427990357681
# 3  {"browser": "Chrome", "browserVersion": "not a...  9075655783635761930
# 4  {"browser": "Chrome", "browserVersion": "not a...  6960673291025684308
#
#                                           geoNetwork  \
# 0  {"continent": "Europe", "subContinent": "Weste...
# 1  {"continent": "Americas", "subContinent": "Nor...
# 2  {"continent": "Americas", "subContinent": "Nor...
# 3  {"continent": "Asia", "subContinent": "Western...
# 4  {"continent": "Americas", "subContinent": "Cen...
#
#                                                 hits  socialEngagementType  \
# 0  [{'hitNumber': '1', 'time': '0', 'hour': '17',...  Not Socially Engaged
# 1  [{'hitNumber': '1', 'time': '0', 'hour': '10',...  Not Socially Engaged
# 2  [{'hitNumber': '1', 'time': '0', 'hour': '17',...  Not Socially Engaged
# 3  [{'hitNumber': '1', 'time': '0', 'hour': '9', ...  Not Socially Engaged
# 4  [{'hitNumber': '1', 'time': '0', 'hour': '14',...  Not Socially Engaged
#
#                                               totals  \
# 0  {"visits": "1", "hits": "1", "pageviews": "1",...
# 1  {"visits": "1", "hits": "2", "pageviews": "2",...
# 2  {"visits": "1", "hits": "2", "pageviews": "2",...
# 3  {"visits": "1", "hits": "2", "pageviews": "2",...
# 4  {"visits": "1", "hits": "2", "pageviews": "2",...
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {"campaign": "(not set)", "source": "google", ...  1508198450            1
# 1  {"referralPath": "/a/google.com/transportation...  1508176307            6
# 2  {"campaign": "(not set)", "source": "(direct)"...  1508201613            1
# 3  {"campaign": "(not set)", "source": "google", ...  1508169851            1
# 4  {"campaign": "(not set)", "source": "google", ...  1508190552            1
#
#    visitStartTime
# 0      1508198450
# 1      1508176307
# 2      1508201613
# 3      1508169851
# 4      1508190552

# %% [markdown]
# As we can see, there are 4 columns with JSON data:
# - device
# - geoNetwork
# - hits
# - totals
# - trafficSource
#
# Let's write a function to load this data and flatten these JSON data in columns. The work will be based on [Leonardo Ferreira's kernel](https://www.kaggle.com/kabure/exploring-the-consumer-patterns-ml-pipeline).
#
# ## Flattening JSON columns and loading a random subset of the data

# %%
# json_columns: Columns that have json format
# p is a fractional number to skiprows and read just a random sample of the our dataset. 
def json_read(filepath, p=0.07, parseHitsAndCustomDimensions=False):
    json_columns = ['device', 'geoNetwork', 'totals', 'trafficSource']
    df = pd.read_csv(filepath, 
                     converters={column: json.loads for column in json_columns}, # loading the json columns properly
                     dtype={'fullVisitorId': 'str'}, # transforming this column to string
                     skiprows=lambda i: i>0 and random.random() > p)# Number of rows that will be imported randomly
    
    if parseHitsAndCustomDimensions:
        # Parse hits column
        df['hits'] = df['hits'].apply(literal_eval)
        df['hits'] = df['hits'].str[0]
        to_replace_keys = ['time',
         'hour',
         'minute',
         'isInteraction',
         'isEntrance',
         'isExit',
         'referer',
         'page',
         'transaction',
         'item',
         'appInfo',
         'exceptionInfo',
         'product',
         'promotion',
         'eCommerceAction',
         'experiment',
         'customVariables',
         'customDimensions',
         'customMetrics',
         'type',
         'social',
         'contentGroup',
         'dataSource',
         'publisher_infos']

        to_replace = {key:np.NaN for key in to_replace_keys}
        df['hits'] = df['hits'].apply(lambda x: to_replace if pd.isnull(x) else x)

        # Parse customDimensions column
        df['customDimensions'] = df['customDimensions'].apply(literal_eval)
        df['customDimensions'] = df['customDimensions'].str[0]
        df['customDimensions'] = df['customDimensions'].apply(lambda x: {'index':np.NaN,'value':np.NaN} if pd.isnull(x) else x)

        json_columns = ['device', 'geoNetwork', 'totals', 'trafficSource','hits','customDimensions']
    
    
    for column in json_columns: #loop to finally transform the columns in data frame
        #It will normalize and set the json to a table
        column_as_df = json_normalize(df[column]) 
        # here will be set the name using the category and subcategory of json columns
        column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns] 
        # after extracting the values, let drop the original columns
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
        
    print(f"Loaded {os.path.basename(filepath)}. Shape: {df.shape}")
    return df

# %%
# %%time
train = json_read('input/train_v2.csv', p=0.1)
# Out:
# Loaded train_v2.csv. Shape: (170954, 59)
# CPU times: user 1min 20s, sys: 18.7 s, total: 1min 38s
# Wall time: 2min

# %%
print(train.info())
pd.set_option('display.max_columns', None) # To show all columns in .head()
train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170954 entries, 0 to 170953
# Data columns (total 59 columns):
# channelGrouping                                      170954 non-null object
# customDimensions                                     170954 non-null object
# date                                                 170954 non-null int64
# fullVisitorId                                        170954 non-null object
# hits                                                 170954 non-null object
# socialEngagementType                                 170954 non-null object
# visitId                                              170954 non-null int64
# visitNumber                                          170954 non-null int64
# visitStartTime                                       170954 non-null int64
# device.browser                                       170954 non-null object
# device.browserSize                                   170954 non-null object
# device.browserVersion                                170954 non-null object
# device.deviceCategory                                170954 non-null object
# device.flashVersion                                  170954 non-null object
# device.isMobile                                      170954 non-null bool
# device.language                                      170954 non-null object
# device.mobileDeviceBranding                          170954 non-null object
# device.mobileDeviceInfo                              170954 non-null object
# device.mobileDeviceMarketingName                     170954 non-null object
# device.mobileDeviceModel                             170954 non-null object
# device.mobileInputSelector                           170954 non-null object
# device.operatingSystem                               170954 non-null object
# device.operatingSystemVersion                        170954 non-null object
# device.screenColors                                  170954 non-null object
# device.screenResolution                              170954 non-null object
# geoNetwork.city                                      170954 non-null object
# geoNetwork.cityId                                    170954 non-null object
# geoNetwork.continent                                 170954 non-null object
# geoNetwork.country                                   170954 non-null object
# geoNetwork.latitude                                  170954 non-null object
# geoNetwork.longitude                                 170954 non-null object
# geoNetwork.metro                                     170954 non-null object
# geoNetwork.networkDomain                             170954 non-null object
# geoNetwork.networkLocation                           170954 non-null object
# geoNetwork.region                                    170954 non-null object
# geoNetwork.subContinent                              170954 non-null object
# totals.bounces                                       87333 non-null object
# totals.hits                                          170954 non-null object
# totals.newVisits                                     130867 non-null object
# totals.pageviews                                     170931 non-null object
# totals.sessionQualityDim                             87333 non-null object
# totals.timeOnSite                                    83349 non-null object
# totals.totalTransactionRevenue                       1880 non-null object
# totals.transactionRevenue                            1880 non-null object
# totals.transactions                                  1883 non-null object
# totals.visits                                        170954 non-null object
# trafficSource.adContent                              6303 non-null object
# trafficSource.adwordsClickInfo.adNetworkType         7394 non-null object
# trafficSource.adwordsClickInfo.criteriaParameters    170954 non-null object
# trafficSource.adwordsClickInfo.gclId                 7406 non-null object
# trafficSource.adwordsClickInfo.isVideoAd             7394 non-null object
# trafficSource.adwordsClickInfo.page                  7394 non-null object
# trafficSource.adwordsClickInfo.slot                  7394 non-null object
# trafficSource.campaign                               170954 non-null object
# trafficSource.isTrueDirect                           53728 non-null object
# trafficSource.keyword                                65138 non-null object
# trafficSource.medium                                 170954 non-null object
# trafficSource.referralPath                           56802 non-null object
# trafficSource.source                                 170954 non-null object
# dtypes: bool(1), int64(4), object(54)
# memory usage: 75.8+ MB
# None
#   channelGrouping                            customDimensions      date  \
# 0  Organic Search           [{'index': '4', 'value': 'EMEA'}]  20171016
# 1  Organic Search           [{'index': '4', 'value': 'APAC'}]  20171016
# 2  Organic Search           [{'index': '4', 'value': 'APAC'}]  20171016
# 3  Organic Search           [{'index': '4', 'value': 'EMEA'}]  20171016
# 4        Referral  [{'index': '4', 'value': 'North America'}]  20171016
#
#          fullVisitorId                                               hits  \
# 0  1259490915281096752  [{'hitNumber': '1', 'time': '0', 'hour': '7', ...
# 1  6338477365942527347  [{'hitNumber': '1', 'time': '0', 'hour': '11',...
# 2  5634653258298299672  [{'hitNumber': '1', 'time': '0', 'hour': '3', ...
# 3   451521411412093630  [{'hitNumber': '1', 'time': '0', 'hour': '6', ...
# 4  4773414387615233459  [{'hitNumber': '1', 'time': '0', 'hour': '11',...
#
#    socialEngagementType     visitId  visitNumber  visitStartTime  \
# 0  Not Socially Engaged  1508165159            2      1508165159
# 1  Not Socially Engaged  1508177911            1      1508177911
# 2  Not Socially Engaged  1508150872            3      1508150872
# 3  Not Socially Engaged  1508160016            3      1508160016
# 4  Not Socially Engaged  1508177180            2      1508177180
#
#   device.browser             device.browserSize  \
# 0         Safari  not available in demo dataset
# 1     UC Browser  not available in demo dataset
# 2         Chrome  not available in demo dataset
# 3         Chrome  not available in demo dataset
# 4         Chrome  not available in demo dataset
#
#            device.browserVersion device.deviceCategory  \
# 0  not available in demo dataset                mobile
# 1  not available in demo dataset                mobile
# 2  not available in demo dataset                mobile
# 3  not available in demo dataset               desktop
# 4  not available in demo dataset               desktop
#
#              device.flashVersion  device.isMobile  \
# 0  not available in demo dataset             True
# 1  not available in demo dataset             True
# 2  not available in demo dataset             True
# 3  not available in demo dataset            False
# 4  not available in demo dataset            False
#
#                  device.language    device.mobileDeviceBranding  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#          device.mobileDeviceInfo device.mobileDeviceMarketingName  \
# 0  not available in demo dataset    not available in demo dataset
# 1  not available in demo dataset    not available in demo dataset
# 2  not available in demo dataset    not available in demo dataset
# 3  not available in demo dataset    not available in demo dataset
# 4  not available in demo dataset    not available in demo dataset
#
#         device.mobileDeviceModel     device.mobileInputSelector  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   device.operatingSystem  device.operatingSystemVersion  \
# 0                    iOS  not available in demo dataset
# 1                Android  not available in demo dataset
# 2                    iOS  not available in demo dataset
# 3                Windows  not available in demo dataset
# 4                  Linux  not available in demo dataset
#
#              device.screenColors        device.screenResolution  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                  geoNetwork.city              geoNetwork.cityId  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2                         Minato  not available in demo dataset
# 3                        Ixelles  not available in demo dataset
# 4                      Sunnyvale  not available in demo dataset
#
#   geoNetwork.continent geoNetwork.country            geoNetwork.latitude  \
# 0               Europe        Netherlands  not available in demo dataset
# 1                 Asia              India  not available in demo dataset
# 2                 Asia              Japan  not available in demo dataset
# 3               Europe            Belgium  not available in demo dataset
# 4             Americas      United States  not available in demo dataset
#
#             geoNetwork.longitude                   geoNetwork.metro  \
# 0  not available in demo dataset      not available in demo dataset
# 1  not available in demo dataset      not available in demo dataset
# 2  not available in demo dataset                           JP_KANTO
# 3  not available in demo dataset                          (not set)
# 4  not available in demo dataset  San Francisco-Oakland-San Jose CA
#
#   geoNetwork.networkDomain     geoNetwork.networkLocation  \
# 0                (not set)  not available in demo dataset
# 1                (not set)  not available in demo dataset
# 2        panda-world.ne.jp  not available in demo dataset
# 3                (not set)  not available in demo dataset
# 4                (not set)  not available in demo dataset
#
#                geoNetwork.region geoNetwork.subContinent totals.bounces  \
# 0  not available in demo dataset          Western Europe            NaN
# 1  not available in demo dataset           Southern Asia            NaN
# 2                          Tokyo            Eastern Asia            NaN
# 3                       Brussels          Western Europe            NaN
# 4                     California        Northern America            NaN
#
#   totals.hits totals.newVisits totals.pageviews totals.sessionQualityDim  \
# 0           2              NaN                2                        1
# 1           2                1                2                        1
# 2           2              NaN                2                        1
# 3           2              NaN                2                        1
# 4           3              NaN                3                        2
#
#   totals.timeOnSite totals.totalTransactionRevenue totals.transactionRevenue  \
# 0                32                            NaN                       NaN
# 1                73                            NaN                       NaN
# 2                17                            NaN                       NaN
# 3               571                            NaN                       NaN
# 4                31                            NaN                       NaN
#
#   totals.transactions totals.visits trafficSource.adContent  \
# 0                 NaN             1                     NaN
# 1                 NaN             1                     NaN
# 2                 NaN             1                     NaN
# 3                 NaN             1                     NaN
# 4                 NaN             1                     NaN
#
#   trafficSource.adwordsClickInfo.adNetworkType  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   trafficSource.adwordsClickInfo.criteriaParameters  \
# 0                     not available in demo dataset
# 1                     not available in demo dataset
# 2                     not available in demo dataset
# 3                     not available in demo dataset
# 4                     not available in demo dataset
#
#   trafficSource.adwordsClickInfo.gclId  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   trafficSource.adwordsClickInfo.isVideoAd  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   trafficSource.adwordsClickInfo.page trafficSource.adwordsClickInfo.slot  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#   trafficSource.campaign trafficSource.isTrueDirect trafficSource.keyword  \
# 0              (not set)                       True        (not provided)
# 1              (not set)                        NaN        (not provided)
# 2              (not set)                        NaN        (not provided)
# 3              (not set)                       True        (not provided)
# 4              (not set)                       True                   NaN
#
#   trafficSource.medium trafficSource.referralPath trafficSource.source
# 0              organic                        NaN               google
# 1              organic                        NaN               google
# 2              organic                        NaN               google
# 3              organic                        NaN               google
# 4               (none)                          /             (direct)

# %% [markdown]
# ## Checking missing values

# %%
def missing_values(data):
    total = data.isnull().sum().sort_values(ascending = False) # getting the sum of null values and ordering
    percent = (data.isnull().sum() / data.isnull().count() * 100 ).sort_values(ascending = False) #getting the percent and order of null
    df = pd.concat([total, percent], axis=1, keys=['Total', 'Percent']) # Concatenating the total and percent
    df = df[df.Total > 0]
    return df

# %%
pd.set_option('display.max_rows', None) # To show all columns in .head()
missing_df = missing_values(train)
missing_df
# Out:
#                                                Total    Percent
# totals.totalTransactionRevenue                169074  98.900289
# totals.transactionRevenue                     169074  98.900289
# totals.transactions                           169071  98.898534
# trafficSource.adContent                       164651  96.313043
# trafficSource.adwordsClickInfo.slot           163560  95.674860
# trafficSource.adwordsClickInfo.page           163560  95.674860
# trafficSource.adwordsClickInfo.isVideoAd      163560  95.674860
# trafficSource.adwordsClickInfo.adNetworkType  163560  95.674860
# trafficSource.adwordsClickInfo.gclId          163548  95.667840
# trafficSource.isTrueDirect                    117226  68.571663
# trafficSource.referralPath                    114152  66.773518
# trafficSource.keyword                         105816  61.897353
# totals.timeOnSite                              87605  51.244779
# totals.sessionQualityDim                       83621  48.914328
# totals.bounces                                 83621  48.914328
# totals.newVisits                               40087  23.448998
# totals.pageviews                                  23   0.013454

# %%
missing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, totals.totalTransactionRevenue to totals.pageviews
# Data columns (total 2 columns):
# Total      17 non-null int64
# Percent    17 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 408.0+ bytes

# %% [markdown]
# Let's **investigate column by column** to see **what we can drop**.
#
# It is extremely **important to understand what each field means**. [Check BigQuery Export schema](https://support.google.com/analytics/answer/3437719?hl=en).
#
# The first 3 are what (or related to) what we need to predict. The 2nd field, `totals.transactionRevenue`, is deprecated, accordingly to the above documentation. Let's start by dropping it.

# %%
columns_to_drop = ['totals.transactionRevenue']

# %%
train['totals.totalTransactionRevenue'].unique()
# Out:
# array([nan, '22590000', '18390000', ..., '62170000', '245950000',
#        '108260000'], dtype=object)

# %% [markdown]
# We will keep `totals.totalTransactionRevenue`, filling `nan` with `0`, as per [BigQuery documentation](https://support.google.com/analytics/answer/3437719?hl=en). Must be **transformed in integer**.

# %%
train['totals.transactions'].unique()
# Out:
# array([nan, '1', '2', '4', '8', '3', '6', '12'], dtype=object)

# %% [markdown]
# We will keep `totals.transactions`, filling `nan` with `0`, as per [BigQuery documentation](https://support.google.com/analytics/answer/3437719?hl=en). Must be **transformed in integer**.

# %%
train['trafficSource.adContent'].unique()
# Out:
# array([nan, 'Bags 300x250', 'Google Merchandise Store',
#        'Drinkware 336x280', 'Placement Drinkware 300x250',
#        'First Full Auto Template Test Ad', 'Full auto ad IMAGE ONLY',
#        'Official Google Merchandise', 'Display Ad created 3/11/15',
#        'Google Merchandise Collection', 'Display Ad created 3/11/14',
#        'Ad from 12/13/16', 'Placement Accessores 300 x 250',
#        'Placement Accessories 160 x 600', 'BQ', 'Ad from 12/15/17',
#        '{KeyWord:Google Branded Apparel}', 'Display Ad created 11/17/14',
#        'Google Online Store', 'Placement 336x280',
#        '{KeyWord:Google Merchandise}', 'Placement Accessories 336 x 280',
#        'Placement 300 x 250', 'Ad from 12/21/16',
#        'Smart display ad - 8/17/2017', 'Placememnt Drinkware 160x600',
#        '{KeyWord:Google Brand Items}',
#        '{KeyWord:Looking for Google Bags?}',
#        '{KeyWord:Google Branded Kit}', 'Google Store',
#        'Smart display ad - 2/6/2018', 'Swag with Google Logos',
#        'Placement Elecronics 300 x 250', '{KeyWord:Google Drinkware}',
#        'Google Apparel', '20% discount', 'Want Google Sunglasses',
#        'Placement Office 300x250', 'Ad from 11/3/16',
#        'Placement Accessories 300 x 250', 'Bags 160 x 600',
#        'Bags 336x280', 'cool', 'Full auto ad with Primary Color',
#        'Ad from 11/7/16', '{KeyWord:Google Branded Gear}',
#        'Google Merchandise', 'Office 2018 - 120 x 600',
#        'Office Placement 160x600', 'Placement Accessories2 120 x 600',
#        '{KeyWord:Want Google Stickers?}', 'LeEco_1a', 'JD_5a_v1',
#        'Full auto ad TEXT ONLY', 'Placement Electronics 160 x 600'],
#       dtype=object)

# %%
columns_to_drop.append('trafficSource.adContent')

# %%
train['trafficSource.adwordsClickInfo.slot'].unique()
# Out:
# array([nan, 'Top', 'RHS', 'Google Display Network'], dtype=object)

# %% [markdown]
# We will keep `trafficSource.adwordsClickInfo.slot`, filling `nan` with a string `'NA'`.

# %%
train['trafficSource.adwordsClickInfo.page'].unique()
# Out:
# array([nan, '1', '2', '3', '4'], dtype=object)

# %% [markdown]
# We will keep `trafficSource.adwordsClickInfo.page`, filling `nan` with a string `'NA'`.

# %%
train['trafficSource.adwordsClickInfo.isVideoAd'].unique()
# Out:
# array([nan, False], dtype=object)

# %%
columns_to_drop.append('trafficSource.adwordsClickInfo.isVideoAd')

# %%
train['trafficSource.adwordsClickInfo.adNetworkType'].unique()
# Out:
# array([nan, 'Google Search', 'Content'], dtype=object)

# %% [markdown]
# We will keep `trafficSource.adwordsClickInfo.adNetworkType`, filling `nan` with a string `'unknown'`, as per [BigQuery documentation](https://support.google.com/analytics/answer/3437719?hl=en).

# %%
train['trafficSource.adwordsClickInfo.gclId'].unique()
# Out:
# array([nan,
#        'Cj0KCQjwsZHPBRClARIsAC-VMPBv9X_YKr1Llp3ebjZ8fGYQ3J8k1D-ObeGiyZoQqJkiDw2mlBEOGkQaAnohEALw_wcB',
#        'EAIaIQobChMI8KvHj9Tk1gIVSJN-Ch1apQ0EEAAYASAAEgJs-fD_BwE', ...,
#        'CjwKEAiA17LDBRDElqOGq8vR7m8SJAA1AC0_hkB5KnHHZg7njwjlMFtGTynPAasTX-zYl8ZT3w0wBxoCaYTw_wcB',
#        'CLqy-drBqdECFZO2wAodhBoKYw',
#        'CjwKEAiA17LDBRDElqOGq8vR7m8SJAA1AC0_iEqMo2ShjHFC8J4wtgs358y2AWkRwaGtVK1jMpI_gRoCr13w_wcB'],
#       dtype=object)

# %%
columns_to_drop.append('trafficSource.adwordsClickInfo.gclId')

# %%
train['trafficSource.isTrueDirect'].unique()
# Out:
# array([True, nan], dtype=object)

# %% [markdown]
# We will keep `trafficSource.isTrueDirect`, filling `nan` with a string `False`, as per [BigQuery documentation](https://support.google.com/analytics/answer/3437719?hl=en). . Must be **transformed in boolean**.

# %%
train['trafficSource.referralPath'].unique()
# Out:
# array([nan, '/', '/gopher', ..., '/intl/it/yt/creators/benefits/silver/',
#        '/yt/lineups/ru/france.html', '/mail/mu/mp/118/'], dtype=object)

# %%
columns_to_drop.append('trafficSource.referralPath')

# %%
train['trafficSource.keyword'].unique()
# Out:
# array(['(not provided)', nan, '6qEhsCssdK0z36ri',
#        '(Remarketing/Content targeting)', '(User vertical targeting)',
#        'Google mens', '(automatic matching)', '1X4Me6ZKNV0zg-jV',
#        '1hZbAqLCbjwfgOH7', 'android clothes', 'store merchandise',
#        'googlemerch', 'Youtube shop', 'google store', 'google online',
#        'youteb', 'men 3x youtube', 'google merchandise store',
#        'Google t shirt', 'Google Merchandise', 'DoubleClick Ad Exchange',
#        'youtube diary merchqndise', 'google shop', 'google developer',
#        'www google', 'www.google.com', 'shirt with tshirt',
#        'google merchandise', 'youtube t shirt', 'youtube 0',
#        'google online store', 'google mugs', 'Google merchandise',
#        'google s5icker', 'You tube', 'you todu', 'youtueb', 'youtube',
#        'merchandise backpacks', 'shirt merchandise',
#        '+Google +Merchandise', 'googlemerchandisestore.com',
#        'https://www.googlemerchandisestore.com/',
#        'mr price boys white t shirt',
#        'what.can you write on t-shirts family?', 'fyoutube',
#        'YouTube tshirt', '+google +stores', 'youtube merch',
#        '+google +merchandise +store', 'يوتتوب', '+google +store',
#        'YouTube Merchandise', '+google +store +merchandise',
#        'google apparel', '+youtube +merch', '+YouTube +Merchandise',
#        'youtube tshirt', 'youtubu', '+YouTube +Products',
#        'free google t shirt',
#        't shirts on which you tube sis written for women', 'shop youtube',
#        'youtube youtube', 'google shopping company', 'www google co usa',
#        'youtube clothing', 'YOuTube', 'vintage usa t shirt', 'WWW.GOOGLE',
#        'www youtube in', 'you tube', 'buy youtube t shirt',
#        'lather lamps for sale', 'koleksi tshirt di rumah ayakan wonogiri',
#        'Google shop', 'lava lamp', 'shop merchandise',
#        't shirts for men united states', 'Google io t shirts',
#        'Google t shirts india', 'play.googgle.com/store/',
#        'google note book', 'youtuhe', 'you thube',
#        'Shopping › Apparel › Casual Apparel › T-Shirts',
#        'google t shirt india', 'awesome android pirate graphic tees',
#        'google backpack', 'google fanware', '+google +coffee +mug',
#        'google stores', 'youtube merchandise', 'google deutschland',
#        'google local guide t shirt buy', 'google gym bag',
#        '+google +backpack', 'you tubi', 'yub tube', 'google fold up cap',
#        'shopgoogle', '+Google +Products', '+google +apperal',
#        'Www google', 'Google Online Store', 'google short', 'YouTube',
#        'google android laptop', 'YUTUB FILME ONLINE XXXL',
#        'youtube t-shirt buy online in india', 'category_l1==166',
#        'google smartphone neue', 'google shirt', 'google brasil',
#        'cheapest mammos violet/red lava lamp', 'Merchandaise Google, Com',
#        'youtube store', 'shope on google', 'www goglee',
#        'vintage tees womens', 'waterproof backpack', 'YouTube shop',
#        'google crhome store', '+Google +accessories', 'yiouutbe',
#        'what are apparel tshirts', 'wakazapost tishet',
#        'google developer merchandise', 'google',
#        'google merchandise store los angeles', 'магазины gift от google',
#        'store you tube', 'youyuve', 'shart gogle.',
#        'how to gwt google firevade tshirt', 'Google Merchandise Store',
#        'google app store', 'Google store Seattle', 'google laptop',
#        'you tou', 'yout toub', 'lava lamps', '谷歌store', 'youtyube',
#        'www com youtube', '+mens +sunglasses', 'we are on google sticker',
#        'The Google Merchandise Store', 'google merch', 'apparel',
#        't shirt shopping', 'merchandise store online',
#        'https://goto.google.com/a/google.com?continue=https://goto.google.com/onlinestore',
#        'google apparel store', 'google trucker hat', 'R39 ses flat top',
#        'tienda online google', 'google t shirt free', 'you tube home',
#        'your tube', 'YOUTUBE', 'Youtube', 'Bicycle Google shopping',
#        'store', 'Youtube tshart',
#        'how to order own youtube chanel name t shirts',
#        'red nose go kart youtube', 'buy google official tshirt', 'bag',
#        'youtyue', 'yourtube', 'ютуб', 'youtuvb', 'youtubr',
#        'mens t shirt online shopping', 'u tube store',
#        'Amazone shopping u tube', 'google chrome storee',
#        'is youtube google', 'google company store', '+merchandise +store',
#        'pagina de youtube', 'google t shirt', 'merchandise store',
#        'youtoube', "Google men's price", 'google gray hood zipup',
#        'google e shopping', 'google t shirt store', '(content targeting)',
#        'www youttube', 'Jutub', 'outube', 'ytoutube',
#        'google powerbank miceneo', 'google shop youtube jacke',
#        'google gifts', 'google now review', 'yotube', 'youtube sotere',
#        'youtubbr', '+google +water +bottle', 'Www.google store.com',
#        'google items for sale', 'google gadget stores', 'youtob',
#        'shop google', 'laptop backpack', 'micro wireless earphone',
#        'youtube merchandise store', 'google and plugged in merchandise',
#        'google chrome store', 'buy google merchandise', 'google t-shirt',
#        'Google developer t-shirt', 'Google store',
#        'शर्ट का साईज S M XL L YOU TUBE', 'merchandise',
#        'googgle cor mens', 'tshirta for youtube video', '+Google +Gear',
#        'youtujbe', 'jaket google dev', '4 99', 'Google accessories',
#        'google shops', 'youtubea', 'Google stickers', 'youtube shirt',
#        'google android mug', '+google +merch', 'Google Gear',
#        'youte youb', 'yotubbe', 'utube', 'google hooded t shirt',
#        'youtuve', 'bags', 'youtube printed tshirts', 'youttube',
#        'youtube shop', '+google +mug', 'tee', 'googke merhadiestore',
#        'where we can find the clothing and accessories in google demo account',
#        'youtube t shirt online', 'https://goto.google.com/tyctwd-shirts',
#        'google thermal bottle',
#        'https://goto.google.com/a/google.com?continue=https://goto.google.com/tyctwd-shirts',
#        'you yutbe', 'youtube t-shirts mean online shopping', 'youtove',
#        'google brand shirt', 'Google Merchandise Store Mountain View, CA',
#        'youtube backpack merch', 'google store merchandise',
#        't shirt zdillog', 'merchandise indian youtuber',
#        'merchandise google', 'youtube web', 'yo utube', 'google astore',
#        'google t shirts', 'Yt merch', '71817', 'youtube brand store',
#        'youtubd', 'Google grefy', 'Googl.com.tisart..xom',
#        'laptop backpack bags', 'youyubr', 'store google', 'youtubey',
#        '+google +store +usa', 'GOOGLE MERCH STORE', 'google shirt online',
#        't shirt shop', 'youtube gaming merch', 'google T shirts',
#        'yoputubr', 'youtoobe', '7dog', 'YOU TUBE', 'oyutube',
#        'google water bottle', 'Googl tee rizal', 'design tshirts store',
#        'merchandise clothing store', 'accessories google cloud',
#        '+Google +Swag', 'yoztube', 'Google Merchandising store',
#        'youtube u', 'about google merchandise store', 'google swag gear',
#        'youtube t shirt india azon', 'GoogleMerchandise.com',
#        'googlestore', 'yutrube', 'youtubge', 'google bags',
#        'online google store', 'kerana store youtube',
#        'free google back pack', 'google ti shirt', 'google tshirt',
#        'free google stickers', 'You Tube clothing', 'google the website',
#        'google in store', 'Arts & Entertainment', 'google logo bag',
#        'Google Developer t shirt', 'you utbe', 'google headphones',
#        'https:shop:googlemerchandisestore.com',
#        '40 watt bulb for lava lamp', 'youtube logo merch', 'yotubee',
#        'google shirt 29_15 price', 'google login laden', 'youtube.cpm',
#        'youtube stickers', 'who will get google bags', 'youtube hat',
#        'google hoodie', 'yout ube', 'google kids com', 'google fleece',
#        'Google merchandise store', '+google +bags', 'youtube a',
#        'shop merchandise store.com', 'google.com/swag',
#        'google official merchandise', 'u5sQvJGpOsPeJ3pi', 'нщгегиу',
#        'hoodie', 'clava duffel bag', 'google store mexico',
#        'Google shirts', 'YouTube YouTube', 'you tubbe',
#        'online sale by google', 'Google partner accessories',
#        'Google online office close store', 'electronic stores',
#        'google e store', 'Google shrit com', 'google electronics',
#        'tahirt logo at voogle style', 'google stickers', 'www.gool',
#        'Sing up Google shirt', 'online merchandise shop',
#        'youtube jacket', 'how to get google stickers for your laptops',
#        'youtuber merch',
#        'https://www.theverge.com/2018/1/19/16911408/vr-chat-virtual-reality-seizure',
#        'you tube shirt philippines for sale', 'youtube la',
#        'gogal branded', 'android product store', 'youtubew',
#        'googles store', 'google italia', 'goole store', 'youtube logo',
#        'google store hoodie', 'googlemen', 'y tube',
#        'how to get google T-shirts', 'online store merchandise',
#        'google beanie', 'google store us', 'Google vintage',
#        'google print t shirt for man', 'حقيبة غوغل',
#        'www.Google shop.com', 'YouTube t shirts', 'YOUTUBE JACKETS',
#        'merchandise online shop', '+google +products +store',
#        'Google Tシャツ', 'buy google jackets', 'google store international',
#        'Google store in Sydney', 'андроид сторе', 'Google ietams.com',
#        'how to get google developer t shirt', 'Googles T sharts',
#        'youu tube', 'yutubve', 'youbute', 'powerbank',
#        'hoodie zipper google', 'www googlr', 'merchandise bags', 'yutybe',
#        'Lifestyle range google', 'Hat google', 'YouTube accessories',
#        'www goo', 'yotuube', 'buy youtube tshirt', '+the +google +shop',
#        'youtube hoodies', 'youtube logu t shart',
#        'Google keyboard stiker', 'google sweatshirts',
#        'alifya souvenir google +', 'google store.ca',
#        'free youtube t shirt', 'youtube google', 'google deutsch shop',
#        'water bottle', 'lava lamps amazon', 'store shirt',
#        'view google com', 'buy google cycle', 'YouTube merch',
#        'red gool gle tshart', 'google brand',
#        'redhatter video merchandise', 'www.google', 'google thermostat',
#        'merchandise online store', 'google items', 'you thbe', 'youtoup',
#        'www.gogle chrome', 'bag shop', 'red neon lava lamps',
#        'youtube youtube youtube youtube youtube', 'google t',
#        'what does a tumbler do in a water bottle', 'googlestore.com',
#        'yotube goodies online buy', 'kids garments merchandise',
#        'where to buy google shirt', 'google logo t shirt',
#        'www.fensi Tisurt imegs.com', 'you yube',
#        'https://www.googlemerchandisestore.com/shop.axd/Home',
#        'googler merchandise', 'google t恤 online store',
#        'jara brand germents mens t- shirt', '+YouTube +accessories',
#        'google gift card', 'youtube merchendise indonesia',
#        'google merchansing stores', 'google merchandising',
#        'youtube printed t shirt', 'google mug', 'merchandise android',
#        'youtuber merch indonesia', 'YouTube Bolger tshirts reward level',
#        'sign in google', 'google usa store', 'you tu b',
#        'Official T-shirt extended', 'kickball for sale',
#        'online market melalui google',
#        'cara dapat merchandise dari google', 'youtubde', 'youtubes',
#        'toddler skateboard', 'blue green crayon', 'frodo merch youtube',
#        'tyutube', 'yubetube', 'YouTube hoodie', 'Youtube merch', 'Yutube',
#        'laptop backpack lightweight', 'get free clothes from google',
#        'googlemerchandisestore', 'youtobe', 'i want pic of T shrit',
#        'youtube youtube youtube', 'Store', 'yautub',
#        'buy youtube merchandise in india', 'google store italia',
#        'bags com in', 'http://bit.ly/2rbJMWb', 'google shirt buy',
#        'youtube tshirts', 'android goodies shop', 'Google hizen stoor',
#        'google merchandice', 'you tuble', 'you tube store',
#        'google marchandise store', '구글 usa', 'android stickers',
#        'Youtube jackets', 't shirt with google logo',
#        'google online shopping', 'google hats for sale', 'uou tube',
#        'category_l1==222', 'Merchandise Store', 'gogle store',
#        'google merchandise store login', 'yt merch', 'close youtube',
#        'you tob', 'You Tube', 'uotyob', 'youtube bright eyes',
#        'google bluetooth headph', 'youtube online store',
#        'www ezmail com man t sart', 'online apparel', 'goog yu tubl',
#        'google notebook', 'google merchandise store uk', 'tumbler bottle',
#        'yiutube', 'you tuybe', 'youtube cap', 'gogole merhandise store',
#        'you tubeđ', 'youtope', 'you tjbe', 'u tue', 'google power bank',
#        'www.google store', 'youubr', 'youtne', 'yo utbe', 'You.tube',
#        'youtube kamukta.com store', 'google steckar', 'ouube',
#        'google merchant store', 'merchandise youtuber indonesia',
#        'youtubemağaza', 'onlinestore with Google', 'black tube',
#        'youtuu be', 'shop Google gift cards', 't shirt online store',
#        'google clothes', 'wwww google', 'google pen', 'yutuve',
#        'water bottles', 'Google YouTube', 'Www.goglestore.Com',
#        'essilor kids merchandise', 'YouTube Merchandise Store', 'yutub',
#        'pen', 'youtube name t shirt buy online', 'google fan shop',
#        'Youtube All stors', 'wwwgoog', 'tshirts', 't shirt google',
#        'google store san diego', 'Google bag', 'You tude',
#        'shop on google', '+google +stor', 'google shopping USA', 'yutupe',
#        'yuo tube', 'ykutube', 'Www.google shirt.com',
#        'youtube logo t shirt', 'google chrome gadgets',
#        'merchandise google store', 'you tbe', 'youtibe', 'yyoutube',
#        'Google chrome tshirts', 'you tube t shirts', 'tee shirt',
#        'google tee', 'oytube', 'youtubwe', 'official youtube merchandise',
#        'google + online', 'google white t shirt', 'google store LINE',
#        'Googleonline', 'merch youtube', 't-shirt',
#        'white t shirts HD pic', 'you tube accessories',
#        'google play online store', 'google shop apps',
#        'google water bottels', 'youtoub',
#        'women t-shirt with the icon of you tube in iy', 'google eshop',
#        'side zipper sweatshirt for mens', 'google t shirt online',
#        'google merchandise india', 'head gear store',
#        'fayiki mr low on t shirt', 'volcano lamps at ebay',
#        'google devlopers t shirt', 'youtube.com', 'yioutubbe',
#        'larver lamps big', 'shopping channel canada',
#        '+google +store +products', 'www goggle', 'youtube on',
#        'youtube website', 'austrailia google', 'Google pens', 'tyoutube',
#        'kids t-shirts', 'mens tee shirts',
#        'download name Tuduetso T-shirt', 'Google baba stickers',
#        'www.google.com pept shirt',
#        'https://www.google.com/appserve/mkt/p/AIQrb_4XfMVyqlEOUqtWB1vVjvujeBxabGq2u6OMGSEaX-Tamo7BqEYMQ3N0OzLdfUtzKS0UGB04Dx8GykA2eTT7RUwns-IycDHc1Rk1auS5tMPeRuTGz74mVUMJSRPLc2ePtWz5TKBcTVmkvEkpA8c',
#        'https://www.google.com/appserve/mkt/p/AIQrb_6L66F4ve1p9ZzBUXuLzOn05oE8NTr-8r9hTeiXYvEEZoWUD3S1O785YlbE9hY8sUe4z8_4ItmHLk1klR9yNFMF_VIqLBElztrWG2DUc6IDSXTTMg367amoanOf9kLeUochJ_Yu4FFPuuPVLmj4_Q',
#        "men's google", 'googlet', 'yuo bube', 'google bag',
#        'free google tshirt', 'google online shop', 'google con',
#        'yiutubr', 'shirt for women', 'youutb e', 'youitube', 'youtuob',
#        'youtube apparel', 'youTube men', 'acheter goodie google au usa',
#        'hat google buy', 'Sarastmmonte Babor er T shirt',
#        'google t shirt shop', 'google t-shirt bangladesh',
#        'online shopping google', 'यौ ट्यूब', 'youtubhe', 'wind up toy',
#        'Google cycle shopping', 'goggle store', 'merchandise t shirt',
#        'shops in Google', 'yoitube', 'outub', 't shirts online shopping',
#        'google shop online', 'googleplex store',
#        'youtube t shirt india online', 'goo goo baby t shirt',
#        'gopher google', 'google google', 'Google Store',
#        'google developers tshirt', 'Google Banner mugs',
#        'google partners notebook', 'yutubr',
#        'age19waight50hight5ft4inch s boy', 'google storw', 'youtu',
#        'buy google logo pen', 'be you man tee',
#        'https://www.googlemerchandisestore.com', 'Google store backpack',
#        'bag Google', 'ou tube', 'Tera mini store socks download',
#        'you tove', 'YouTube logo t-shirt', 'yotule',
#        't shirt google shop', '+YouTube +kit', 'youty', 'google zip',
#        'Google Logo T- Shirt Shopping', 'sticker', 'tou tube',
#        'google merchafise', 'ストア グーグル', 'travel bag branded',
#        'You tube t-shirt', 'official shirt with logo', 'youtube s',
#        'leatherette journal', 'you tup', 'store apparel', 'google usa',
#        'buy google gift cards', 'google shopping online',
#        'google store youtube', 'utubr', 'ютюб', '+YouTube +Gear',
#        'youtube t shirt buy', 'apparel shops', 'merchandise shops',
#        'merchandis stor asia', 'GOOGLE OFFICIAL MARCHIDISE',
#        'google swag', 'Merchandise', 'funny android bot',
#        'merchandise clothes united states', 'buy t shirts',
#        'bag googal.com',
#        "Google Men's 100% Cotton Short Sleeve Hero Tee White",
#        'google+ shop', 'big lava lamp', 'youtube t shirt for men',
#        'Google developer hoodie', 'google t shirt uk', 'google商店官网',
#        'google store .com', '+google +shop', 'google io logo',
#        'youtube fliptop', 'where can i get an original youtube t shirt',
#        'shop google merchandise', 'google bike buy', 'You.tobe',
#        'गूगल शर्ट प्राइस', 'googlesupport', 'Google T-shart', 'жбоь7 цом',
#        'free google shop', 'google usa home', 'youtubne', 'googlr store',
#        'www.Google store.com', 'apperal', 'order a google merchandise',
#        'yu tube', 't shirt', 'google google google', 'shorter google'],
#       dtype=object)

# %%
columns_to_drop.append('trafficSource.keyword')

# %% [markdown]
# For now we will drop `trafficSource.keyword`, but we should figure it out a way to use it.
#
# For example: checking the top 10 searched terms (words in the keyword column), and creating 10 columns with boolean `is_term_present_in_keyword`.

# %%
train['totals.timeOnSite'].unique()
# Out:
# array(['32', '73', '17', ..., '2872', '8313', '1991'], dtype=object)

# %% [markdown]
# The column `'totals.timeOnSite'` can be completed by transforming it in integers and filling `nan` with mean. Must be **transformed in integer**.

# %%
train['totals.sessionQualityDim'].unique()
# Out:
# array(['1', '2', '8', '3', '7', '11', '28', '9', '14', '16', '21', '12',
#        '72', '58', '6', '4', '56', '88', '23', '79', '67', '51', nan,
#        '17', '34', '27', '61', '5', '65', '45', '68', '73', '71', '60',
#        '90', '64', '86', '70', '46', '41', '15', '37', '76', '84', '31',
#        '10', '32', '42', '75', '74', '33', '25', '39', '78', '52', '53',
#        '44', '87', '26', '48', '30', '24', '55', '35', '63', '13', '83',
#        '43', '18', '59', '38', '85', '22', '82', '29', '20', '47', '19',
#        '81', '66', '95', '57', '49', '94', '50', '91', '40', '80', '77',
#        '89', '36', '96', '69', '62', '54', '93', '92', '98', '99'],
#       dtype=object)

# %% [markdown]
# We will keep `totals.sessionQualityDim`, filling `nan` with `0`, as per [BigQuery documentation](https://support.google.com/analytics/answer/3437719?hl=en). Must be **transformed in integer**.

# %%
train['totals.bounces'].unique()
# Out:
# array([nan, '1'], dtype=object)

# %% [markdown]
# We will keep `totals.bounces`, filling `nan` with `0`, as per [BigQuery documentation](https://support.google.com/analytics/answer/3437719?hl=en). Must be **transformed in integer**.

# %%
train['totals.newVisits'].unique()
# Out:
# array([nan, '1'], dtype=object)

# %% [markdown]
# We will keep `totals.newVisits`, filling `nan` with `0`, as per [BigQuery documentation](https://support.google.com/analytics/answer/3437719?hl=en). Must be **transformed in integer**.

# %%
train['totals.pageviews'].unique()
# Out:
# array(['2', '3', '4', '5', '6', '7', '8', '9', '10', '13', '11', '12',
#        '16', '14', '17', '22', '31', '28', '61', '15', '1', '18', '19',
#        '21', '20', '24', '25', '34', '33', '32', '40', '44', '90', '29',
#        '26', '39', '43', nan, '48', '23', '35', '45', '58', '49', '30',
#        '47', '27', '37', '38', '52', '46', '36', '103', '104', '230',
#        '41', '56', '69', '51', '50', '73', '118', '57', '86', '66', '75',
#        '105', '80', '60', '54', '62', '94', '67', '79', '59', '42', '55',
#        '71', '53', '333', '77', '64', '68', '81', '140', '102', '85',
#        '76', '74', '115', '150', '96', '84', '101', '63', '143', '189',
#        '91', '223', '92', '112', '78', '97', '65', '309', '72', '188',
#        '176', '88', '270', '107', '120', '87', '179', '108', '129', '82',
#        '114', '323', '351', '132', '139', '111', '70', '100', '185', '99',
#        '98', '159', '109', '119', '340', '250', '161', '83', '312', '110',
#        '113', '201'], dtype=object)

# %% [markdown]
# The column `'totals.pageviews'` can be completed by transforming it in integers and filling `nan` with mean. Must be **transformed in integer**.

# %%
print(columns_to_drop)
train.drop(columns_to_drop, axis=1, inplace=True)
# Out:
# ['totals.transactionRevenue', 'trafficSource.adContent', 'trafficSource.adwordsClickInfo.isVideoAd', 'trafficSource.adwordsClickInfo.gclId', 'trafficSource.referralPath', 'trafficSource.keyword']

# %%
print(train.shape)
train.head()
# Out:
# (170954, 53)
#   channelGrouping                            customDimensions      date  \
# 0  Organic Search           [{'index': '4', 'value': 'EMEA'}]  20171016
# 1  Organic Search           [{'index': '4', 'value': 'APAC'}]  20171016
# 2  Organic Search           [{'index': '4', 'value': 'APAC'}]  20171016
# 3  Organic Search           [{'index': '4', 'value': 'EMEA'}]  20171016
# 4        Referral  [{'index': '4', 'value': 'North America'}]  20171016
#
#          fullVisitorId                                               hits  \
# 0  1259490915281096752  [{'hitNumber': '1', 'time': '0', 'hour': '7', ...
# 1  6338477365942527347  [{'hitNumber': '1', 'time': '0', 'hour': '11',...
# 2  5634653258298299672  [{'hitNumber': '1', 'time': '0', 'hour': '3', ...
# 3   451521411412093630  [{'hitNumber': '1', 'time': '0', 'hour': '6', ...
# 4  4773414387615233459  [{'hitNumber': '1', 'time': '0', 'hour': '11',...
#
#    socialEngagementType     visitId  visitNumber  visitStartTime  \
# 0  Not Socially Engaged  1508165159            2      1508165159
# 1  Not Socially Engaged  1508177911            1      1508177911
# 2  Not Socially Engaged  1508150872            3      1508150872
# 3  Not Socially Engaged  1508160016            3      1508160016
# 4  Not Socially Engaged  1508177180            2      1508177180
#
#   device.browser             device.browserSize  \
# 0         Safari  not available in demo dataset
# 1     UC Browser  not available in demo dataset
# 2         Chrome  not available in demo dataset
# 3         Chrome  not available in demo dataset
# 4         Chrome  not available in demo dataset
#
#            device.browserVersion device.deviceCategory  \
# 0  not available in demo dataset                mobile
# 1  not available in demo dataset                mobile
# 2  not available in demo dataset                mobile
# 3  not available in demo dataset               desktop
# 4  not available in demo dataset               desktop
#
#              device.flashVersion  device.isMobile  \
# 0  not available in demo dataset             True
# 1  not available in demo dataset             True
# 2  not available in demo dataset             True
# 3  not available in demo dataset            False
# 4  not available in demo dataset            False
#
#                  device.language    device.mobileDeviceBranding  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#          device.mobileDeviceInfo device.mobileDeviceMarketingName  \
# 0  not available in demo dataset    not available in demo dataset
# 1  not available in demo dataset    not available in demo dataset
# 2  not available in demo dataset    not available in demo dataset
# 3  not available in demo dataset    not available in demo dataset
# 4  not available in demo dataset    not available in demo dataset
#
#         device.mobileDeviceModel     device.mobileInputSelector  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   device.operatingSystem  device.operatingSystemVersion  \
# 0                    iOS  not available in demo dataset
# 1                Android  not available in demo dataset
# 2                    iOS  not available in demo dataset
# 3                Windows  not available in demo dataset
# 4                  Linux  not available in demo dataset
#
#              device.screenColors        device.screenResolution  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                  geoNetwork.city              geoNetwork.cityId  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2                         Minato  not available in demo dataset
# 3                        Ixelles  not available in demo dataset
# 4                      Sunnyvale  not available in demo dataset
#
#   geoNetwork.continent geoNetwork.country            geoNetwork.latitude  \
# 0               Europe        Netherlands  not available in demo dataset
# 1                 Asia              India  not available in demo dataset
# 2                 Asia              Japan  not available in demo dataset
# 3               Europe            Belgium  not available in demo dataset
# 4             Americas      United States  not available in demo dataset
#
#             geoNetwork.longitude                   geoNetwork.metro  \
# 0  not available in demo dataset      not available in demo dataset
# 1  not available in demo dataset      not available in demo dataset
# 2  not available in demo dataset                           JP_KANTO
# 3  not available in demo dataset                          (not set)
# 4  not available in demo dataset  San Francisco-Oakland-San Jose CA
#
#   geoNetwork.networkDomain     geoNetwork.networkLocation  \
# 0                (not set)  not available in demo dataset
# 1                (not set)  not available in demo dataset
# 2        panda-world.ne.jp  not available in demo dataset
# 3                (not set)  not available in demo dataset
# 4                (not set)  not available in demo dataset
#
#                geoNetwork.region geoNetwork.subContinent totals.bounces  \
# 0  not available in demo dataset          Western Europe            NaN
# 1  not available in demo dataset           Southern Asia            NaN
# 2                          Tokyo            Eastern Asia            NaN
# 3                       Brussels          Western Europe            NaN
# 4                     California        Northern America            NaN
#
#   totals.hits totals.newVisits totals.pageviews totals.sessionQualityDim  \
# 0           2              NaN                2                        1
# 1           2                1                2                        1
# 2           2              NaN                2                        1
# 3           2              NaN                2                        1
# 4           3              NaN                3                        2
#
#   totals.timeOnSite totals.totalTransactionRevenue totals.transactions  \
# 0                32                            NaN                 NaN
# 1                73                            NaN                 NaN
# 2                17                            NaN                 NaN
# 3               571                            NaN                 NaN
# 4                31                            NaN                 NaN
#
#   totals.visits trafficSource.adwordsClickInfo.adNetworkType  \
# 0             1                                          NaN
# 1             1                                          NaN
# 2             1                                          NaN
# 3             1                                          NaN
# 4             1                                          NaN
#
#   trafficSource.adwordsClickInfo.criteriaParameters  \
# 0                     not available in demo dataset
# 1                     not available in demo dataset
# 2                     not available in demo dataset
# 3                     not available in demo dataset
# 4                     not available in demo dataset
#
#   trafficSource.adwordsClickInfo.page trafficSource.adwordsClickInfo.slot  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#   trafficSource.campaign trafficSource.isTrueDirect trafficSource.medium  \
# 0              (not set)                       True              organic
# 1              (not set)                        NaN              organic
# 2              (not set)                        NaN              organic
# 3              (not set)                       True              organic
# 4              (not set)                       True               (none)
#
#   trafficSource.source
# 0               google
# 1               google
# 2               google
# 3               google
# 4             (direct)

# %% [markdown]
# ## Filling NAs and parsing columns to numeric values

# %%
def fill_nan_values(df):
    df['totals.totalTransactionRevenue'].fillna('0', inplace=True)
    df['totals.totalTransactionRevenue'] = df['totals.totalTransactionRevenue'].astype(float)
    
    df['totals.transactions'].fillna('0', inplace=True)
    df['totals.transactions'] = df['totals.transactions'].astype(int)
    
    df['trafficSource.adwordsClickInfo.slot'].fillna('NA', inplace=True)
    df['trafficSource.adwordsClickInfo.page'].fillna('NA', inplace=True)
    df['trafficSource.adwordsClickInfo.adNetworkType'].fillna('unknown', inplace=True)
    df['trafficSource.isTrueDirect'].fillna(False, inplace=True)
    df['trafficSource.isTrueDirect'] = df['trafficSource.isTrueDirect'].astype('bool')
    
    df['totals.timeOnSite'] = df['totals.timeOnSite'].astype(float)
    df['totals.timeOnSite'].fillna(df['totals.timeOnSite'].mean(), inplace=True)
    df['totals.timeOnSite'] = df['totals.timeOnSite'].astype(int)
    
    df['totals.sessionQualityDim'].fillna('0', inplace=True)
    df['totals.sessionQualityDim'] = df['totals.sessionQualityDim'].astype(int)
    
    df['totals.bounces'].fillna('0', inplace=True)
    df['totals.bounces'] = df['totals.bounces'].astype(int)
    
    df['totals.newVisits'].fillna('0', inplace=True)
    df['totals.newVisits'] = df['totals.newVisits'].astype(int)
    
    df['totals.pageviews'] = df['totals.pageviews'].astype(float)
    df['totals.pageviews'].fillna(df['totals.pageviews'].mean(), inplace=True)
    df['totals.pageviews'] = df['totals.pageviews'].astype(int)
    
    df['totals.hits'] = df['totals.hits'].astype(int)

# %%
fill_nan_values(train)
train.head()
# Out:
#   channelGrouping                            customDimensions      date  \
# 0  Organic Search           [{'index': '4', 'value': 'EMEA'}]  20171016
# 1  Organic Search           [{'index': '4', 'value': 'APAC'}]  20171016
# 2  Organic Search           [{'index': '4', 'value': 'APAC'}]  20171016
# 3  Organic Search           [{'index': '4', 'value': 'EMEA'}]  20171016
# 4        Referral  [{'index': '4', 'value': 'North America'}]  20171016
#
#          fullVisitorId                                               hits  \
# 0  1259490915281096752  [{'hitNumber': '1', 'time': '0', 'hour': '7', ...
# 1  6338477365942527347  [{'hitNumber': '1', 'time': '0', 'hour': '11',...
# 2  5634653258298299672  [{'hitNumber': '1', 'time': '0', 'hour': '3', ...
# 3   451521411412093630  [{'hitNumber': '1', 'time': '0', 'hour': '6', ...
# 4  4773414387615233459  [{'hitNumber': '1', 'time': '0', 'hour': '11',...
#
#    socialEngagementType     visitId  visitNumber  visitStartTime  \
# 0  Not Socially Engaged  1508165159            2      1508165159
# 1  Not Socially Engaged  1508177911            1      1508177911
# 2  Not Socially Engaged  1508150872            3      1508150872
# 3  Not Socially Engaged  1508160016            3      1508160016
# 4  Not Socially Engaged  1508177180            2      1508177180
#
#   device.browser             device.browserSize  \
# 0         Safari  not available in demo dataset
# 1     UC Browser  not available in demo dataset
# 2         Chrome  not available in demo dataset
# 3         Chrome  not available in demo dataset
# 4         Chrome  not available in demo dataset
#
#            device.browserVersion device.deviceCategory  \
# 0  not available in demo dataset                mobile
# 1  not available in demo dataset                mobile
# 2  not available in demo dataset                mobile
# 3  not available in demo dataset               desktop
# 4  not available in demo dataset               desktop
#
#              device.flashVersion  device.isMobile  \
# 0  not available in demo dataset             True
# 1  not available in demo dataset             True
# 2  not available in demo dataset             True
# 3  not available in demo dataset            False
# 4  not available in demo dataset            False
#
#                  device.language    device.mobileDeviceBranding  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#          device.mobileDeviceInfo device.mobileDeviceMarketingName  \
# 0  not available in demo dataset    not available in demo dataset
# 1  not available in demo dataset    not available in demo dataset
# 2  not available in demo dataset    not available in demo dataset
# 3  not available in demo dataset    not available in demo dataset
# 4  not available in demo dataset    not available in demo dataset
#
#         device.mobileDeviceModel     device.mobileInputSelector  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   device.operatingSystem  device.operatingSystemVersion  \
# 0                    iOS  not available in demo dataset
# 1                Android  not available in demo dataset
# 2                    iOS  not available in demo dataset
# 3                Windows  not available in demo dataset
# 4                  Linux  not available in demo dataset
#
#              device.screenColors        device.screenResolution  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                  geoNetwork.city              geoNetwork.cityId  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2                         Minato  not available in demo dataset
# 3                        Ixelles  not available in demo dataset
# 4                      Sunnyvale  not available in demo dataset
#
#   geoNetwork.continent geoNetwork.country            geoNetwork.latitude  \
# 0               Europe        Netherlands  not available in demo dataset
# 1                 Asia              India  not available in demo dataset
# 2                 Asia              Japan  not available in demo dataset
# 3               Europe            Belgium  not available in demo dataset
# 4             Americas      United States  not available in demo dataset
#
#             geoNetwork.longitude                   geoNetwork.metro  \
# 0  not available in demo dataset      not available in demo dataset
# 1  not available in demo dataset      not available in demo dataset
# 2  not available in demo dataset                           JP_KANTO
# 3  not available in demo dataset                          (not set)
# 4  not available in demo dataset  San Francisco-Oakland-San Jose CA
#
#   geoNetwork.networkDomain     geoNetwork.networkLocation  \
# 0                (not set)  not available in demo dataset
# 1                (not set)  not available in demo dataset
# 2        panda-world.ne.jp  not available in demo dataset
# 3                (not set)  not available in demo dataset
# 4                (not set)  not available in demo dataset
#
#                geoNetwork.region geoNetwork.subContinent  totals.bounces  \
# 0  not available in demo dataset          Western Europe               0
# 1  not available in demo dataset           Southern Asia               0
# 2                          Tokyo            Eastern Asia               0
# 3                       Brussels          Western Europe               0
# 4                     California        Northern America               0
#
#    totals.hits  totals.newVisits  totals.pageviews  totals.sessionQualityDim  \
# 0            2                 0                 2                         1
# 1            2                 1                 2                         1
# 2            2                 0                 2                         1
# 3            2                 0                 2                         1
# 4            3                 0                 3                         2
#
#    totals.timeOnSite  totals.totalTransactionRevenue  totals.transactions  \
# 0                 32                             0.0                    0
# 1                 73                             0.0                    0
# 2                 17                             0.0                    0
# 3                571                             0.0                    0
# 4                 31                             0.0                    0
#
#   totals.visits trafficSource.adwordsClickInfo.adNetworkType  \
# 0             1                                      unknown
# 1             1                                      unknown
# 2             1                                      unknown
# 3             1                                      unknown
# 4             1                                      unknown
#
#   trafficSource.adwordsClickInfo.criteriaParameters  \
# 0                     not available in demo dataset
# 1                     not available in demo dataset
# 2                     not available in demo dataset
# 3                     not available in demo dataset
# 4                     not available in demo dataset
#
#   trafficSource.adwordsClickInfo.page trafficSource.adwordsClickInfo.slot  \
# 0                                  NA                                  NA
# 1                                  NA                                  NA
# 2                                  NA                                  NA
# 3                                  NA                                  NA
# 4                                  NA                                  NA
#
#   trafficSource.campaign  trafficSource.isTrueDirect trafficSource.medium  \
# 0              (not set)                        True              organic
# 1              (not set)                       False              organic
# 2              (not set)                       False              organic
# 3              (not set)                        True              organic
# 4              (not set)                        True               (none)
#
#   trafficSource.source
# 0               google
# 1               google
# 2               google
# 3               google
# 4             (direct)

# %% [markdown]
# ## Checking missing values again

# %%
missing_df = missing_values(train)
missing_df
# Out:
# Empty DataFrame
# Columns: [Total, Percent]
# Index: []

# %% [markdown]
# ## Feature engineering: dates

# %%
from datetime import datetime

def date_process(df):
    df["date"] = pd.to_datetime(df["date"], format="%Y%m%d")
    df["_weekday"] = df['date'].dt.weekday
    df["_day"] = df['date'].dt.day
    df["_month"] = df['date'].dt.month
    df["_year"] = df['date'].dt.year
    df['_visitHour'] = (df['visitStartTime'].apply(lambda x: str(datetime.fromtimestamp(x).hour))).astype(int)
    return df

# %%
train = date_process(train)

# %%
train.head()
# Out:
#   channelGrouping                            customDimensions       date  \
# 0  Organic Search           [{'index': '4', 'value': 'EMEA'}] 2017-10-16
# 1  Organic Search           [{'index': '4', 'value': 'APAC'}] 2017-10-16
# 2  Organic Search           [{'index': '4', 'value': 'APAC'}] 2017-10-16
# 3  Organic Search           [{'index': '4', 'value': 'EMEA'}] 2017-10-16
# 4        Referral  [{'index': '4', 'value': 'North America'}] 2017-10-16
#
#          fullVisitorId                                               hits  \
# 0  1259490915281096752  [{'hitNumber': '1', 'time': '0', 'hour': '7', ...
# 1  6338477365942527347  [{'hitNumber': '1', 'time': '0', 'hour': '11',...
# 2  5634653258298299672  [{'hitNumber': '1', 'time': '0', 'hour': '3', ...
# 3   451521411412093630  [{'hitNumber': '1', 'time': '0', 'hour': '6', ...
# 4  4773414387615233459  [{'hitNumber': '1', 'time': '0', 'hour': '11',...
#
#    socialEngagementType     visitId  visitNumber  visitStartTime  \
# 0  Not Socially Engaged  1508165159            2      1508165159
# 1  Not Socially Engaged  1508177911            1      1508177911
# 2  Not Socially Engaged  1508150872            3      1508150872
# 3  Not Socially Engaged  1508160016            3      1508160016
# 4  Not Socially Engaged  1508177180            2      1508177180
#
#   device.browser             device.browserSize  \
# 0         Safari  not available in demo dataset
# 1     UC Browser  not available in demo dataset
# 2         Chrome  not available in demo dataset
# 3         Chrome  not available in demo dataset
# 4         Chrome  not available in demo dataset
#
#            device.browserVersion device.deviceCategory  \
# 0  not available in demo dataset                mobile
# 1  not available in demo dataset                mobile
# 2  not available in demo dataset                mobile
# 3  not available in demo dataset               desktop
# 4  not available in demo dataset               desktop
#
#              device.flashVersion  device.isMobile  \
# 0  not available in demo dataset             True
# 1  not available in demo dataset             True
# 2  not available in demo dataset             True
# 3  not available in demo dataset            False
# 4  not available in demo dataset            False
#
#                  device.language    device.mobileDeviceBranding  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#          device.mobileDeviceInfo device.mobileDeviceMarketingName  \
# 0  not available in demo dataset    not available in demo dataset
# 1  not available in demo dataset    not available in demo dataset
# 2  not available in demo dataset    not available in demo dataset
# 3  not available in demo dataset    not available in demo dataset
# 4  not available in demo dataset    not available in demo dataset
#
#         device.mobileDeviceModel     device.mobileInputSelector  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   device.operatingSystem  device.operatingSystemVersion  \
# 0                    iOS  not available in demo dataset
# 1                Android  not available in demo dataset
# 2                    iOS  not available in demo dataset
# 3                Windows  not available in demo dataset
# 4                  Linux  not available in demo dataset
#
#              device.screenColors        device.screenResolution  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                  geoNetwork.city              geoNetwork.cityId  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2                         Minato  not available in demo dataset
# 3                        Ixelles  not available in demo dataset
# 4                      Sunnyvale  not available in demo dataset
#
#   geoNetwork.continent geoNetwork.country            geoNetwork.latitude  \
# 0               Europe        Netherlands  not available in demo dataset
# 1                 Asia              India  not available in demo dataset
# 2                 Asia              Japan  not available in demo dataset
# 3               Europe            Belgium  not available in demo dataset
# 4             Americas      United States  not available in demo dataset
#
#             geoNetwork.longitude                   geoNetwork.metro  \
# 0  not available in demo dataset      not available in demo dataset
# 1  not available in demo dataset      not available in demo dataset
# 2  not available in demo dataset                           JP_KANTO
# 3  not available in demo dataset                          (not set)
# 4  not available in demo dataset  San Francisco-Oakland-San Jose CA
#
#   geoNetwork.networkDomain     geoNetwork.networkLocation  \
# 0                (not set)  not available in demo dataset
# 1                (not set)  not available in demo dataset
# 2        panda-world.ne.jp  not available in demo dataset
# 3                (not set)  not available in demo dataset
# 4                (not set)  not available in demo dataset
#
#                geoNetwork.region geoNetwork.subContinent  totals.bounces  \
# 0  not available in demo dataset          Western Europe               0
# 1  not available in demo dataset           Southern Asia               0
# 2                          Tokyo            Eastern Asia               0
# 3                       Brussels          Western Europe               0
# 4                     California        Northern America               0
#
#    totals.hits  totals.newVisits  totals.pageviews  totals.sessionQualityDim  \
# 0            2                 0                 2                         1
# 1            2                 1                 2                         1
# 2            2                 0                 2                         1
# 3            2                 0                 2                         1
# 4            3                 0                 3                         2
#
#    totals.timeOnSite  totals.totalTransactionRevenue  totals.transactions  \
# 0                 32                             0.0                    0
# 1                 73                             0.0                    0
# 2                 17                             0.0                    0
# 3                571                             0.0                    0
# 4                 31                             0.0                    0
#
#   totals.visits trafficSource.adwordsClickInfo.adNetworkType  \
# 0             1                                      unknown
# 1             1                                      unknown
# 2             1                                      unknown
# 3             1                                      unknown
# 4             1                                      unknown
#
#   trafficSource.adwordsClickInfo.criteriaParameters  \
# 0                     not available in demo dataset
# 1                     not available in demo dataset
# 2                     not available in demo dataset
# 3                     not available in demo dataset
# 4                     not available in demo dataset
#
#   trafficSource.adwordsClickInfo.page trafficSource.adwordsClickInfo.slot  \
# 0                                  NA                                  NA
# 1                                  NA                                  NA
# 2                                  NA                                  NA
# 3                                  NA                                  NA
# 4                                  NA                                  NA
#
#   trafficSource.campaign  trafficSource.isTrueDirect trafficSource.medium  \
# 0              (not set)                        True              organic
# 1              (not set)                       False              organic
# 2              (not set)                       False              organic
# 3              (not set)                        True              organic
# 4              (not set)                        True               (none)
#
#   trafficSource.source  _weekday  _day  _month  _year  _visitHour
# 0               google         0    16      10   2017          12
# 1               google         0    16      10   2017          16
# 2               google         0    16      10   2017           8
# 3               google         0    16      10   2017          11
# 4             (direct)         0    16      10   2017          16

# %% [markdown]
# ## Checking unique values in columns

# %%
train.nunique()
# Out:
# channelGrouping                                           8
# customDimensions                                          6
# date                                                    638
# fullVisitorId                                        161331
# hits                                                 155742
# socialEngagementType                                      1
# visitId                                              170319
# visitNumber                                             262
# visitStartTime                                       170338
# device.browser                                           47
# device.browserSize                                        1
# device.browserVersion                                     1
# device.deviceCategory                                     3
# device.flashVersion                                       1
# device.isMobile                                           2
# device.language                                           1
# device.mobileDeviceBranding                               1
# device.mobileDeviceInfo                                   1
# device.mobileDeviceMarketingName                          1
# device.mobileDeviceModel                                  1
# device.mobileInputSelector                                1
# device.operatingSystem                                   19
# device.operatingSystemVersion                             1
# device.screenColors                                       1
# device.screenResolution                                   1
# geoNetwork.city                                         807
# geoNetwork.cityId                                         1
# geoNetwork.continent                                      6
# geoNetwork.country                                      201
# geoNetwork.latitude                                       1
# geoNetwork.longitude                                      1
# geoNetwork.metro                                        108
# geoNetwork.networkDomain                              11170
# geoNetwork.networkLocation                                1
# geoNetwork.region                                       439
# geoNetwork.subContinent                                  23
# totals.bounces                                            2
# totals.hits                                             178
# totals.newVisits                                          2
# totals.pageviews                                        138
# totals.sessionQualityDim                                 99
# totals.timeOnSite                                      2799
# totals.totalTransactionRevenue                         1359
# totals.transactions                                       8
# totals.visits                                             1
# trafficSource.adwordsClickInfo.adNetworkType              3
# trafficSource.adwordsClickInfo.criteriaParameters         1
# trafficSource.adwordsClickInfo.page                       5
# trafficSource.adwordsClickInfo.slot                       4
# trafficSource.campaign                                   29
# trafficSource.isTrueDirect                                2
# trafficSource.medium                                      7
# trafficSource.source                                    190
# _weekday                                                  7
# _day                                                     31
# _month                                                   12
# _year                                                     3
# _visitHour                                               24
# dtype: int64

# %% [markdown]
# As we can see, there's a lot of columns with **only one** value. These columns can be dropped. Let's do that.

# %%
columns_with_one_value = [col for col in train.columns if train[col].nunique() == 1]
print(columns_with_one_value)
train.drop(columns_with_one_value, axis=1, inplace=True)
# Out:
# ['socialEngagementType', 'device.browserSize', 'device.browserVersion', 'device.flashVersion', 'device.language', 'device.mobileDeviceBranding', 'device.mobileDeviceInfo', 'device.mobileDeviceMarketingName', 'device.mobileDeviceModel', 'device.mobileInputSelector', 'device.operatingSystemVersion', 'device.screenColors', 'device.screenResolution', 'geoNetwork.cityId', 'geoNetwork.latitude', 'geoNetwork.longitude', 'geoNetwork.networkLocation', 'totals.visits', 'trafficSource.adwordsClickInfo.criteriaParameters']

# %%
print(train.shape)
train.head()
# Out:
# (170954, 39)
#   channelGrouping                            customDimensions       date  \
# 0  Organic Search           [{'index': '4', 'value': 'EMEA'}] 2017-10-16
# 1  Organic Search           [{'index': '4', 'value': 'APAC'}] 2017-10-16
# 2  Organic Search           [{'index': '4', 'value': 'APAC'}] 2017-10-16
# 3  Organic Search           [{'index': '4', 'value': 'EMEA'}] 2017-10-16
# 4        Referral  [{'index': '4', 'value': 'North America'}] 2017-10-16
#
#          fullVisitorId                                               hits  \
# 0  1259490915281096752  [{'hitNumber': '1', 'time': '0', 'hour': '7', ...
# 1  6338477365942527347  [{'hitNumber': '1', 'time': '0', 'hour': '11',...
# 2  5634653258298299672  [{'hitNumber': '1', 'time': '0', 'hour': '3', ...
# 3   451521411412093630  [{'hitNumber': '1', 'time': '0', 'hour': '6', ...
# 4  4773414387615233459  [{'hitNumber': '1', 'time': '0', 'hour': '11',...
#
#       visitId  visitNumber  visitStartTime device.browser  \
# 0  1508165159            2      1508165159         Safari
# 1  1508177911            1      1508177911     UC Browser
# 2  1508150872            3      1508150872         Chrome
# 3  1508160016            3      1508160016         Chrome
# 4  1508177180            2      1508177180         Chrome
#
#   device.deviceCategory  device.isMobile device.operatingSystem  \
# 0                mobile             True                    iOS
# 1                mobile             True                Android
# 2                mobile             True                    iOS
# 3               desktop            False                Windows
# 4               desktop            False                  Linux
#
#                  geoNetwork.city geoNetwork.continent geoNetwork.country  \
# 0  not available in demo dataset               Europe        Netherlands
# 1  not available in demo dataset                 Asia              India
# 2                         Minato                 Asia              Japan
# 3                        Ixelles               Europe            Belgium
# 4                      Sunnyvale             Americas      United States
#
#                     geoNetwork.metro geoNetwork.networkDomain  \
# 0      not available in demo dataset                (not set)
# 1      not available in demo dataset                (not set)
# 2                           JP_KANTO        panda-world.ne.jp
# 3                          (not set)                (not set)
# 4  San Francisco-Oakland-San Jose CA                (not set)
#
#                geoNetwork.region geoNetwork.subContinent  totals.bounces  \
# 0  not available in demo dataset          Western Europe               0
# 1  not available in demo dataset           Southern Asia               0
# 2                          Tokyo            Eastern Asia               0
# 3                       Brussels          Western Europe               0
# 4                     California        Northern America               0
#
#    totals.hits  totals.newVisits  totals.pageviews  totals.sessionQualityDim  \
# 0            2                 0                 2                         1
# 1            2                 1                 2                         1
# 2            2                 0                 2                         1
# 3            2                 0                 2                         1
# 4            3                 0                 3                         2
#
#    totals.timeOnSite  totals.totalTransactionRevenue  totals.transactions  \
# 0                 32                             0.0                    0
# 1                 73                             0.0                    0
# 2                 17                             0.0                    0
# 3                571                             0.0                    0
# 4                 31                             0.0                    0
#
#   trafficSource.adwordsClickInfo.adNetworkType  \
# 0                                      unknown
# 1                                      unknown
# 2                                      unknown
# 3                                      unknown
# 4                                      unknown
#
#   trafficSource.adwordsClickInfo.page trafficSource.adwordsClickInfo.slot  \
# 0                                  NA                                  NA
# 1                                  NA                                  NA
# 2                                  NA                                  NA
# 3                                  NA                                  NA
# 4                                  NA                                  NA
#
#   trafficSource.campaign  trafficSource.isTrueDirect trafficSource.medium  \
# 0              (not set)                        True              organic
# 1              (not set)                       False              organic
# 2              (not set)                       False              organic
# 3              (not set)                        True              organic
# 4              (not set)                        True               (none)
#
#   trafficSource.source  _weekday  _day  _month  _year  _visitHour
# 0               google         0    16      10   2017          12
# 1               google         0    16      10   2017          16
# 2               google         0    16      10   2017           8
# 3               google         0    16      10   2017          11
# 4             (direct)         0    16      10   2017          16

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170954 entries, 0 to 170953
# Data columns (total 39 columns):
# channelGrouping                                 170954 non-null object
# customDimensions                                170954 non-null object
# date                                            170954 non-null datetime64[ns]
# fullVisitorId                                   170954 non-null object
# hits                                            170954 non-null object
# visitId                                         170954 non-null int64
# visitNumber                                     170954 non-null int64
# visitStartTime                                  170954 non-null int64
# device.browser                                  170954 non-null object
# device.deviceCategory                           170954 non-null object
# device.isMobile                                 170954 non-null bool
# device.operatingSystem                          170954 non-null object
# geoNetwork.city                                 170954 non-null object
# geoNetwork.continent                            170954 non-null object
# geoNetwork.country                              170954 non-null object
# geoNetwork.metro                                170954 non-null object
# geoNetwork.networkDomain                        170954 non-null object
# geoNetwork.region                               170954 non-null object
# geoNetwork.subContinent                         170954 non-null object
# totals.bounces                                  170954 non-null int64
# totals.hits                                     170954 non-null int64
# totals.newVisits                                170954 non-null int64
# totals.pageviews                                170954 non-null int64
# totals.sessionQualityDim                        170954 non-null int64
# totals.timeOnSite                               170954 non-null int64
# totals.totalTransactionRevenue                  170954 non-null float64
# totals.transactions                             170954 non-null int64
# trafficSource.adwordsClickInfo.adNetworkType    170954 non-null object
# trafficSource.adwordsClickInfo.page             170954 non-null object
# trafficSource.adwordsClickInfo.slot             170954 non-null object
# trafficSource.campaign                          170954 non-null object
# trafficSource.isTrueDirect                      170954 non-null bool
# trafficSource.medium                            170954 non-null object
# trafficSource.source                            170954 non-null object
# _weekday                                        170954 non-null int64
# _day                                            170954 non-null int64
# _month                                          170954 non-null int64
# _year                                           170954 non-null int64
# _visitHour                                      170954 non-null int64
# dtypes: bool(2), datetime64[ns](1), float64(1), int64(15), object(20)
# memory usage: 48.6+ MB

# %% [markdown]
# ## Calculate the prediction column

# %%
def transform_prediction(df):
    df['totals.totalTransactionRevenue'] = df['totals.totalTransactionRevenue'].apply(lambda x: np.log1p(x))
    return df

# %%
train = transform_prediction(train)

# %%
train[train['totals.totalTransactionRevenue'] > 0]['totals.totalTransactionRevenue'].count()
# Out:
# 1880

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170954 entries, 0 to 170953
# Data columns (total 39 columns):
# channelGrouping                                 170954 non-null object
# customDimensions                                170954 non-null object
# date                                            170954 non-null datetime64[ns]
# fullVisitorId                                   170954 non-null object
# hits                                            170954 non-null object
# visitId                                         170954 non-null int64
# visitNumber                                     170954 non-null int64
# visitStartTime                                  170954 non-null int64
# device.browser                                  170954 non-null object
# device.deviceCategory                           170954 non-null object
# device.isMobile                                 170954 non-null bool
# device.operatingSystem                          170954 non-null object
# geoNetwork.city                                 170954 non-null object
# geoNetwork.continent                            170954 non-null object
# geoNetwork.country                              170954 non-null object
# geoNetwork.metro                                170954 non-null object
# geoNetwork.networkDomain                        170954 non-null object
# geoNetwork.region                               170954 non-null object
# geoNetwork.subContinent                         170954 non-null object
# totals.bounces                                  170954 non-null int64
# totals.hits                                     170954 non-null int64
# totals.newVisits                                170954 non-null int64
# totals.pageviews                                170954 non-null int64
# totals.sessionQualityDim                        170954 non-null int64
# totals.timeOnSite                               170954 non-null int64
# totals.totalTransactionRevenue                  170954 non-null float64
# totals.transactions                             170954 non-null int64
# trafficSource.adwordsClickInfo.adNetworkType    170954 non-null object
# trafficSource.adwordsClickInfo.page             170954 non-null object
# trafficSource.adwordsClickInfo.slot             170954 non-null object
# trafficSource.campaign                          170954 non-null object
# trafficSource.isTrueDirect                      170954 non-null bool
# trafficSource.medium                            170954 non-null object
# trafficSource.source                            170954 non-null object
# _weekday                                        170954 non-null int64
# _day                                            170954 non-null int64
# _month                                          170954 non-null int64
# _year                                           170954 non-null int64
# _visitHour                                      170954 non-null int64
# dtypes: bool(2), datetime64[ns](1), float64(1), int64(15), object(20)
# memory usage: 48.6+ MB
